# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 25.9 MB/s eta 0:00:00

# %%
from ultralytics  import YOLO
model=YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 215MB/s]

# %%
# !touch data.yaml

# %%
model.train(data="/content/data.yaml",epochs=6)#fine tunning
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer=YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
infer.predict("/content/gdrive/MyDrive/test/images",save=True,save_txt=True)
# Out:
# image 1/75 /content/gdrive/MyDrive/test/images/383.png: 640x640 1 human, 36.2ms
# image 2/75 /content/gdrive/MyDrive/test/images/384.png: 640x640 1 human, 36.3ms
# image 3/75 /content/gdrive/MyDrive/test/images/385.png: 640x640 1 human, 36.3ms
# image 4/75 /content/gdrive/MyDrive/test/images/386.png: 544x640 1 human, 71.5ms
# image 5/75 /content/gdrive/MyDrive/test/images/387.png: 640x640 2 humans, 37.1ms
# image 6/75 /content/gdrive/MyDrive/test/images/388.png: 640x640 1 human, 36.2ms
# image 7/75 /content/gdrive/MyDrive/test/images/389.png: 640x640 1 human, 36.2ms
# image 8/75 /content/gdrive/MyDrive/test/images/390.png: 640x640 2 humans, 36.3ms
# image 9/75 /content/gdrive/MyDrive/test/images/391.png: 640x640 3 humans, 36.2ms
# image 10/75 /content/gdrive/MyDrive/test/images/392.png: 640x640 2 humans, 36.6ms
# image 11/75 /content/gdrive/MyDrive/test/images/395.png: 640x640 4 humans, 36.3ms
# image 12/75 /content/gdrive/MyDrive/test/images/396.png: 640x640 1 human, 36.3ms
# ...

# %%
import os
command = 'LC_ALL=en_US.UTF-8 LANG=en_US.UTF-8 yolo detect predict model="/content/runs/detect/train2/weights/best.pt" source= "/content/gdrive/MyDrive/WhatsApp Video 2023-05-25 at 14.10.15.mp4"'
os.system(command)
# Out:
# 0
